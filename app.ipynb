# %%
# !pip install Flask
# !pip install langchain
# Out:
# Requirement already satisfied: Flask in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from Flask) (3.0.6)
# Requirement already satisfied: Jinja2>=3.1.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from Flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from Flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from Flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from Flask) (1.8.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from Flask) (8.4.0)
# Requirement already satisfied: colorama in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from importlib-metadata>=3.6.0->Flask) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from Jinja2>=3.1.2->Flask) (3.0.2)
# Requirement already satisfied: langchain in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (0.3.4)
# Requirement already satisfied: PyYAML>=5.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (0.3.13)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)

# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (0.3.4)
# Requirement already satisfied: PyYAML>=5.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (0.3.13)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.16.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -U langchain-community
# !pip install -U jupyter ipywidgets
# cần để xử lý các thành phần trong vectorstores như Chroma
# hệ thống thiếu các gói hỗ trợ Jupyter để hiển thị tiến trình tqdm.
# Out:
# Requirement already satisfied: langchain-community in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (0.3.3)
# Requirement already satisfied: PyYAML>=5.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (0.3.4)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (0.3.13)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (2.6.0)
# Requirement already satisfied: requests<3,>=2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain<0.4.0,>=0.3.4->langchain-community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain<0.4.0,>=0.3.4->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.4->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.4->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.2.2)
# Requirement already satisfied: jupyter in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (1.1.1)
# Requirement already satisfied: ipywidgets in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (8.1.5)
# Requirement already satisfied: notebook in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter) (7.2.2)
# Requirement already satisfied: jupyter-console in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: jupyterlab in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter) (4.2.5)
# Requirement already satisfied: comm>=0.1.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipywidgets) (8.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: exceptiongroup in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: colorama in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: debugpy>=1.6.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipykernel->jupyter) (1.8.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: nest-asyncio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipykernel->jupyter) (24.1)
# Requirement already satisfied: psutil in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipykernel->jupyter) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from ipykernel->jupyter) (6.4.1)
# Requirement already satisfied: async-lru>=1.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (0.27.2)
# Requirement already satisfied: importlib-metadata>=4.8.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (8.4.0)
# Requirement already satisfied: jinja2>=3.0.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.1.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (75.2.0)
# Requirement already satisfied: tomli>=1.2.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab->jupyter) (2.0.2)
# Requirement already satisfied: beautifulsoup4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: six>=1.9.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.6.2.post1)
# Requirement already satisfied: certifi in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.6)
# Requirement already satisfied: idna in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: sniffio in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from importlib-metadata>=4.8.3->jupyterlab->jupyter) (3.20.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: pywin32>=300 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: wcwidth in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: executing>=1.2.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: argon2-cffi-bindings in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.2.3)
# Requirement already satisfied: fqdn in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\sourcecode\git _ pro\cooking-chatbot\cooking-chatbot\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241003)

# %%
from flask import Flask, render_template, request
from langchain.vectorstores import Chroma
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings

# %%
from langchain.chains.question_answering import load_qa_chain  
from langchain.llms import OpenAI
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

# %%
prompt_template='''
Use the following pieces of information to answer the user's question.
If you don't know the answer,just say that you don't know,don't try to makeup the answer.
Context: {context}
Question: {question}

Only return the helpful aswer below and nothing else.
Helpful Answer:
'''

# %%
app = Flask(__name__)


embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectordb=Chroma(persist_directory='db',embedding_function=embeddings)


PROMPT=PromptTemplate(template=prompt_template, input_variables=["context", "question"])

chain_type_kwargs={"prompt": PROMPT}

llm=CTransformers(
    model="TheBloke/Llama-2-7B-Chat-GGML",
    model_type="llama",
    config={'max_new_tokens':2048,'context_length' : 1024,'temperature':0.8}
)

qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectordb.as_retriever(search_kwargs={"k": 2}),
    return_source_documents=True,
    chain_type_kwargs=chain_type_kwargs
)



@app.route("/")
def index():
    return render_template('chat.html')



@app.route("/get", methods=["GET", "POST"])
def chat():
    msg = request.form["msg"]
    input = msg
    print(input)
    result=qa({"query": input})
    print("Response : ", result["result"])
    return str(result["result"])



if __name__ == '__main__':
    app.run(host="0.0.0.0", port= 8080)
# Out:
# C:\Users\VIP\AppData\Local\Temp\ipykernel_26316\1901864551.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# d:\SourceCode\GIT _ PRO\Cooking-Chatbot\COOKING-CHATBOT\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# C:\Users\VIP\AppData\Local\Temp\ipykernel_26316\1901864551.py:5: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectordb=Chroma(persist_directory='db',embedding_function=embeddings)
# ⚠️ It looks like you upgraded from a version below 0.6 and could benefit from vacuuming your database. Run chromadb utils vacuum --help for more information.
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8080
#  * Running on http://192.168.1.14:8080
# Press CTRL+C to quit
